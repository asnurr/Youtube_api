# %%
from googleapiclient.discovery import build
from IPython.display import JSON
import pandas as pd
import time

# %%
YOUTUBE_API_KEY = "AIzaSyCsiehi3w4NW3pXjI0KIvd5-p4TIeCl0qg"

# %%
api_service_name = "youtube"
api_version = "v3"

channel_ids = [
    "Kodluyoruz",
    # Can add more channels
]

# Get credentials and create an API client

youtube = build(
    api_service_name, api_version, developerKey=YOUTUBE_API_KEY)

request = youtube.channels().list(
    part="snippet,contentDetails,statistics",
    id=",".join(channel_ids)
)
response = request.execute()

print(response)
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'RuuXzTIr0OoDqI4S0RU6n4FqKEM', 'pageInfo': {'totalResults': 0, 'resultsPerPage': 5}}

# %%
JSON(response)

# %%
api_service_name = "youtube"
api_version = "v3"

channel_ids = [
    "Kodluyoruz",
    # Can add more channels
]

# Get credentials and create an API client
youtube = build(api_service_name, api_version, developerKey=YOUTUBE_API_KEY)

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []

    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=",".join(channel_ids)
    )

    response = request.execute()

    # loop through items in response
    for item in response["items"]:
        data = {'channelName': item['snippet']['title'],
                'subscribers': item['statistics']['subscriberCount'],
                'views': item['statistics']['viewCount'],
                'totalVideos': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
        }
        all_data.append(data)
    
    return pd.DataFrame(all_data)

# %%
channel_ids = get_channel_stats(youtube, channel_ids)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 channel_ids = get_channel_stats(youtube, channel_ids)
#
# Cell In[32], line 12, in get_channel_stats(youtube, channel_ids)
#       9 response = request.execute()
#      11 # loop through items in response
# ---> 12 for item in response["items"]:
#      13     data = {'channelName': item['snippet']['title'],
#      14             'subscribers': item['statistics']['subscriberCount'],
#      15             'views': item['statistics']['viewCount'],
#      16             'totalVideos': item['statistics']['videoCount'],
#      17             'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
#      18     }
#      19     all_data.append(data)
#
# KeyError: 'items'

# %%
channel_ids
# Out:
# ['Kodluyoruz']

# %%
request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId="PLGrTHqyRDvx6PVwxJmcQ0Veg1uoXRxQY8"
    )
response = request.execute()

# %%
JSON(response)

# %%
def get_video_ids(youtube, playlist_id):
    video_ids = []

    request = youtube.playlistItems().list(
            part="snippet,contentDetails",
            playlistId=playlist_id
        )
    response = request.execute()

    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
    return video_ids

# %%
playlist_id = "PLGrTHqyRDvx6PVwxJmcQ0Veg1uoXRxQY8"

video_ids = get_video_ids(youtube, playlist_id)

# %%
video_ids
# Out:
# ['MB1aScFI8X4', 'cIAXLWUM8WA', 'WuwP8GXAUqE', 'fPRDBf5bU1w']

# %%
def get_video_ids(youtube, playlist_id):
    video_ids = []

    request = youtube.playlistItems().list(
            part="snippet,contentDetails",
            playlistId=playlist_id,
            maxResults=50
        )
    response = request.execute()

    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])

    next_page_token = response.get('nextPageToken')
    
    while next_page_token is not None:
        request = youtube.playlistItems().list(
                part="snippet,contentDetails",
                playlistId=playlist_id,
                maxResults=50,
                pageToken=next_page_token
            )
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')    

        
    return video_ids

# %%
import requests
import pandas as pd

# %%
CHANNEL_ID = "UCSnIf-v95OSGIv9H7d2R2lw"
pageToken = ""
url = "https://www.googleapis.com/youtube/v3/search?key="+YOUTUBE_API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=1000"+pageToken

# %%
print(url)
# Out:
# https://www.googleapis.com/youtube/v3/search?key=AIzaSyCsiehi3w4NW3pXjI0KIvd5-p4TIeCl0qg&channelId=UCSnIf-v95OSGIv9H7d2R2lw&part=snippet,id&order=date&maxResults=1000

# %%
response = requests.get(url).json()

# %%
response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'ErGmcki5u5V2YWn28vcVOiHFBSE',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'TR',
#  'pageInfo': {'totalResults': 438, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'HBWrsle0WGGjEOri8jyHl84s1Ws',
#    'id': {'kind': 'youtube#video', 'videoId': 'SiRbxzKw-hY'},
#    'snippet': {'publishedAt': '2023-12-29T14:41:51Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': 'Başarı Hikayesi | Murat Kiraz',
#     'description': "Başarı Hikayeleri serimizin bu seferki konuğu Murat Kiraz Lisede okuyan Murat'ın yazılıma başlangıç serüveni ve, bu süreçte ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/SiRbxzKw-hY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/SiRbxzKw-hY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/SiRbxzKw-hY/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodluyoruz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-29T14:41:51Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'X5ewA8gXekw5Iqj1K4E3ik14ew8',
#    'id': {'kind': 'youtube#video', 'videoId': '_8bXatPbwE4'},
#    'snippet': {'publishedAt': '2023-12-29T14:41:56Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': 'Başarı Hikayesi | Murat Kiraz',
#     'description': "Başarı Hikayeleri serimizin yeni konuğu Murat Kirazkaya Lisede okuyan Murat'ın yazılıma başlangıç serüvenini, bu süreçte ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_8bXatPbwE4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_8bXatPbwE4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_8bXatPbwE4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodluyoruz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-29T14:41:56Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'qIDZMskyuPQjlibo4Hc5jYjUICM',
#    'id': {'kind': 'youtube#video', 'videoId': 'hS6tJVmiPak'},
#    'snippet': {'publishedAt': '2023-12-27T19:02:06Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': 'Kodluyoruz Adana Ideathon',
#     'description': 'Kodluyoruz Adana Ideathon, teknoloji ve yaratıcılığın harmanlandığı büyüleyici bir deneyimdi! Bu etkinlikte, katılımcılarımızın ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hS6tJVmiPak/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hS6tJVmiPak/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/hS6tJVmiPak/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodluyoruz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-27T19:02:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '__CrCvI_LlwYtAcO1EbZoO-T8HQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'CcgtvPJVwRs'},
#    'snippet': {'publishedAt': '2023-12-26T14:25:17Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': 'Kodluyoruz Yeni İşime Hazırlanıyorum (Ankara)',
#     'description': "15 Aralık'ta Ankara'da Yeni İşime Hazırlanıyorum Programı kapsamında harika bir etkinlik gerçekleştirdik! Katılım sağlayan ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/CcgtvPJVwRs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/CcgtvPJVwRs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/CcgtvPJVwRs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodluyoruz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-26T14:25:17Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'U-0C4sAvzGzN1dJpTGk0B3K5P5c',
#    'id': {'kind': 'youtube#video', 'videoId': '5ogRZC4aE9M'},
#    'snippet': {'publishedAt': '2023-12-14T17:00:03Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': 'Burak Tungut ile Ask Me Anything / Cloud Architect #kodluyoruz #yazılım',
#     'description': 'Cloud bilişim sektörünün başarılı isimlerinden Burak Tungut Ask Me Anything etkinliğimizde, sektöre dair değerli tecrübelerini ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5ogRZC4aE9M/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/5ogRZC4aE9M/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/5ogRZC4aE9M/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodluyoruz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-14T17:00:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'eJBs7Zdvecx4oiu4YjEPqDmSJYk',
#    'id': {'kind': 'youtube#video', 'videoId': 'MYqI51JaE1E'},
#    'snippet': {'publishedAt': '2023-12-14T17:00:31Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': 'Burak Tungut ile Ask Me Anything / Cloud Architect #kodluyoruz #yazılım',
#     'description': 'Cloud bilişim sektörünün başarılı isimlerinden Burak Tungut Ask Me Anything etkinliğimizde, sektöre dair değerli tecrübelerini ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/MYqI51JaE1E/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/MYqI51JaE1E/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/MYqI51JaE1E/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodluyoruz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-14T17:00:31Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Ka8jwcsS0gmQYWz2Jrvu7Pp6FLc',
#    'id': {'kind': 'youtube#video', 'videoId': 'qVEaxW7RYj0'},
#    'snippet': {'publishedAt': '2023-12-09T17:18:10Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': 'Yazılım sektörünün önemli isimlerinden Salih Enver Yurter ile ASK ME ANYTHING  #kodluyoruz #yazılım',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/qVEaxW7RYj0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/qVEaxW7RYj0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/qVEaxW7RYj0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodluyoruz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-09T17:18:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'TvTWu0_y9AecqZIrs6oDIQ1IAM8',
#    'id': {'kind': 'youtube#video', 'videoId': '6fv3EF5mWSA'},
#    'snippet': {'publishedAt': '2023-12-09T16:43:09Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': 'Salih Enver Yurter (Managing Partner @ Avsos) ile Ask Me Anything!',
#     'description': 'Yazılım sektörünün başarılı isimlerinden Enver Yurter (Managing Partner @Avsos), Ask Me Anything etkinliğimizde, sektöre dair ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/6fv3EF5mWSA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/6fv3EF5mWSA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/6fv3EF5mWSA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodluyoruz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-09T16:43:09Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'y9COae5NYwVOEf1oOUkbyxV45P0',
#    'id': {'kind': 'youtube#video', 'videoId': '4cNY5iOabbg'},
#    'snippet': {'publishedAt': '2023-12-06T16:04:24Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': 'Yeni İşime Hazırlanıyorum Programı&#39;nda Neler Yapıyoruz? 🤔 🚀',
#     'description': "Yeni İşime Hazırlanıyorum Programı'na katılan arkadaşlarımızla, programın içeriği, etkinlikler ve edindikleri deneyimler hakkında ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4cNY5iOabbg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/4cNY5iOabbg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/4cNY5iOabbg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodluyoruz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-12-06T16:04:24Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'N9LQ72tg0IB39xCFpQNUp0X2ZGM',
#    'id': {'kind': 'youtube#video', 'videoId': 'E9D99p9mgx8'},
#    'snippet': {'publishedAt': '2023-11-30T15:59:25Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': 'Siber Güvenlik: Geleceğe Yolculuk',
#     'description': "İlyas Süer'in (NGN Bulut Çözümleri Direktörü) unutulmaz Siber Güvenlik: Geleceğe Yolculuk etkinliğini izlediniz mi? Eğer henüz ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/E9D99p9mgx8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/E9D99p9mgx8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/E9D99p9mgx8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodluyoruz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-11-30T15:59:25Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'P_e7_pp2bPFtgqZ5lv2BmRoLV1k',
#    'id': {'kind': 'youtube#video', 'videoId': 'N-utisBoWLo'},
#    'snippet': {'publishedAt': '2023-11-30T09:26:30Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': 'Hard Skills vs Soft Skills | w/Ali Ozan Koçak &amp; Anıl Taşkıran',
#     'description': 'Yeni bir Düello videosuyla karşınızdayız. Bu videoda, Hard Skills vs Soft Skills karşılaştırmalarını yaparak bu alanda uzmanlar ile ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/N-utisBoWLo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/N-utisBoWLo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/N-utisBoWLo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodluyoruz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-11-30T09:26:30Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'wRSfMCkEbd-2-ji8mOtndcMmugQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'DmqMACSBQCg'},
#    'snippet': {'publishedAt': '2023-11-29T16:33:21Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': 'Hard Skills vs Soft Skills | w/ Ozan Koçak &amp; Anıl Taşkıran',
#     'description': 'Yeni bir Düello videosuyla karşınızdayız. Bu videoda, Hard Skills vs Soft Skills karşılaştırmalarını yaparak bu alanda uzmanlar ile ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/DmqMACSBQCg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/DmqMACSBQCg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/DmqMACSBQCg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodluyoruz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-11-29T16:33:21Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '25hX-y9829tUSH62FUfZ7QdljTA',
#    'id': {'kind': 'youtube#video', 'videoId': 's0WKxw9LE4U'},
#    'snippet': {'publishedAt': '2023-11-23T14:01:43Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': 'Daron Yöndem ile Ask Me Anything',
#     'description': "Daron Yöndem'in (Tech Lead @ Microsoft) unutulmaz Ask Me Anything etkinliğini izlediniz mi? Eğer henüz izlemediyseniz ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/s0WKxw9LE4U/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/s0WKxw9LE4U/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/s0WKxw9LE4U/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodluyoruz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-11-23T14:01:43Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'WujANWuz2-HP_ij-iEW9ZfX4isE',
#    'id': {'kind': 'youtube#video', 'videoId': 'fJ7Ca-EH3TI'},
#    'snippet': {'publishedAt': '2023-11-17T19:02:57Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': 'Kodluyoruz 7 yaşında! 🧡',
#     'description': 'Kodluyoruz 7 yaşında! Geçen yıllar, birlikte büyüdüğümüz, öğrendiğimiz ve başardığımız yıllar oldu Sizlerle birlikte elde ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fJ7Ca-EH3TI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fJ7Ca-EH3TI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fJ7Ca-EH3TI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodluyoruz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-11-17T19:02:57Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'L_kSaWlSAvGfVue1lfR2Q_GDDgU',
#    'id': {'kind': 'youtube#video', 'videoId': 'zof6xLbxpZE'},
#    'snippet': {'publishedAt': '2023-11-07T10:55:32Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': 'Yeni İşine Hazırlan: Mülakat Simülasyonu',
#     'description': 'Yazılım dünyasına adım atmak isteyen yetenekli bir adayla gerçek bir mülakat deneyimine tanık olmaya hazır mısınız?',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zof6xLbxpZE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zof6xLbxpZE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zof6xLbxpZE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodluyoruz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-11-07T10:55:32Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'LDCf4bMcK7xl0cTb0W_QjuKxkBc',
#    'id': {'kind': 'youtube#video', 'videoId': '1hWdMu733VA'},
#    'snippet': {'publishedAt': '2023-11-07T10:35:05Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': 'Yeni İşine Hazırlan: Mülakat Simülasyonu - 1. Bölüm',
#     'description': 'Yeni bir Mülakat Simülasyonu videosuyla karşınızdayız. Bu videoda, yazılım dünyasına adım atmak isteyen yetenekli bir adayla ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1hWdMu733VA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/1hWdMu733VA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/1hWdMu733VA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodluyoruz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-11-07T10:35:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '6-Jg7gA8vASJOSiBI50YhfZ6iu4',
#    'id': {'kind': 'youtube#video', 'videoId': 'f1wx9EsQ9Hc'},
#    'snippet': {'publishedAt': '2023-10-27T10:32:53Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': 'Türkiye Cumhuriyeti&#39;nin 100. yıl Kutlu Olsun! 🇹🇷',
#     'description': '100 yıl önce bir rüya başladı. Bir milletin kaderi değişti! Bugün, Cumhuriyetimizin 100. yılında, o rüyayı gerçeğe dönüştürenlerin ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/f1wx9EsQ9Hc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/f1wx9EsQ9Hc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/f1wx9EsQ9Hc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodluyoruz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-10-27T10:32:53Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '-3P2vm6eWIg9emeZCH3az6k42n8',
#    'id': {'kind': 'youtube#video', 'videoId': '4rUMJwO-Vzg'},
#    'snippet': {'publishedAt': '2023-09-16T12:44:56Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': 'Tech&#39;n Talk &amp; Huawei',
#     'description': 'Huawei ve Kodluyoruz\'un işbirliğiyle düzenleyeceğimiz "Tech\'n Talk" etkinliği için büyük bir heyecan duyuyoruz!',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4rUMJwO-Vzg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/4rUMJwO-Vzg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/4rUMJwO-Vzg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodluyoruz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-09-16T12:44:56Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'a1bSHpPZuj8ERQ8XdErepEPaGQI',
#    'id': {'kind': 'youtube#video', 'videoId': 'buyirB6O9tg'},
#    'snippet': {'publishedAt': '2023-09-15T12:44:07Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': 'Tecrübeli Yazılımcı vs Genç Yazılımcı Düello Etkinliği',
#     'description': 'Yazılım alanındaki deneyimlerini paylaşmak için Evren Tan ve Mert Bahardoğan konuklarımız oluyor 00:00 Açılış 00:30 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/buyirB6O9tg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/buyirB6O9tg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/buyirB6O9tg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodluyoruz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2023-09-15T12:44:07Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Ru5hhPJpQYCE-dTrfCnujWLQhGE',
#    'id': {'kind': 'youtube#video', 'videoId': '02-oQAbTg10'},
#    'snippet': {'publishedAt': '2023-08-25T08:01:18Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': '
10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'PrUCfWlQp8DR7qZv1dZOpjPjaAU',
#    'id': {'kind': 'youtube#video', 'videoId': 'vk36mivy9UE'},
#    'snippet': {'publishedAt': '2022-10-14T19:10:03Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': 'Kariyer Sohbetleri:Diplomasız Yazılımcı Olmak',
#     'description': '"Software Developer Ahmet Buğra Çakıcı" Yazılım alanına dair merak ettiğin soruları cevaplayacak.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vk36mivy9UE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vk36mivy9UE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vk36mivy9UE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodluyoruz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-10-14T19:10:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ywrGNqjzRyu0k9hls9ZtXRybQJQ',
#    'id': {'kind': 'youtube#video', 'videoId': '4MuNeJH9PP8'},
#    'snippet': {'publishedAt': '2022-09-23T18:31:25Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': 'Ofiste Çalışmak vs. Evden Çalışmak',
#     'description': '"Senıor DWH/BI Consultant Burak Yolerı" ve "Software Developer Erdem Akyıldız" Ofisten çalışmak ve Evden çalışmak alanlarına ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4MuNeJH9PP8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/4MuNeJH9PP8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/4MuNeJH9PP8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodluyoruz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-09-23T18:31:25Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'gy8i_EnfJB2BrWbQbJkx0hGGF_M',
#    'id': {'kind': 'youtube#video', 'videoId': 'zhamJScIHWE'},
#    'snippet': {'publishedAt': '2022-09-14T18:11:30Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': 'Kariyer Sohbetleri: Veri Bilimi',
#     'description': '"Senior Data Scientist Doruk Çanga" Veri Bilimi alanına dair merak edilen soruları cevaplamak için konuğumuz oluyor.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zhamJScIHWE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zhamJScIHWE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zhamJScIHWE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodluyoruz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-09-14T18:11:30Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'p0IystYSSy7HiFLZBpO5c_WWJRc',
#    'id': {'kind': 'youtube#video', 'videoId': '8fy7idN-YyU'},
#    'snippet': {'publishedAt': '2022-09-10T13:31:23Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': 'Tech&#39;n Talk | Teknoloji ve Yazılım Sektörünün Sesi',
#     'description': 'Azmi Mengü, Bora Kaşmer, Enes Açıkoğlu, Gökhan Ayrancıoğlu, Pınar Yılmazer ve Sinem Ercan “Remote Çalışmak, Domain ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8fy7idN-YyU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/8fy7idN-YyU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/8fy7idN-YyU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodluyoruz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-09-10T13:31:23Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'puK19inwPCWt9ojuAUJ9mjZ42Eo',
#    'id': {'kind': 'youtube#video', 'videoId': 'sno5uOOgzjU'},
#    'snippet': {'publishedAt': '2022-08-25T19:21:51Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': 'Unity vs. Unreal | w/Özge Kocaoğlu &amp; Burak Akşahin',
#     'description': '"Game Programmer Özge Kocaoğlu" ve "Unreal Engine Developer Burak Akşahin" Unity ve Unreal alanlarına dair merak edilen ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/sno5uOOgzjU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/sno5uOOgzjU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/sno5uOOgzjU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodluyoruz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-25T19:21:51Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'zCcT-SljFSztEM_NJL94zmlUOz8',
#    'id': {'kind': 'youtube#video', 'videoId': 'U75Lpq6dzpQ'},
#    'snippet': {'publishedAt': '2022-08-24T18:54:28Z',
#     'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#     'title': 'Eğitimde Office 365 Araçlarının Önemi: Aydın Aslantaş',
#     'description': 'Öğretmenler eğitim verirken teknolojiyi nelerde ve nasıl kullanabilirler? Yazılım bilen bir öğretmen olmanın faydaları nelerdir?',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/U75Lpq6dzpQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/U75Lpq6dzpQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/U75Lpq6dzpQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'Kodluyoruz',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-08-24T18:54:28Z'}}]}

# %%
response["items"][0]
# Out:
# {'kind': 'youtube#searchResult',
#  'etag': 'HBWrsle0WGGjEOri8jyHl84s1Ws',
#  'id': {'kind': 'youtube#video', 'videoId': 'SiRbxzKw-hY'},
#  'snippet': {'publishedAt': '2023-12-29T14:41:51Z',
#   'channelId': 'UCSnIf-v95OSGIv9H7d2R2lw',
#   'title': 'Başarı Hikayesi | Murat Kiraz',
#   'description': "Başarı Hikayeleri serimizin bu seferki konuğu Murat Kiraz Lisede okuyan Murat'ın yazılıma başlangıç serüveni ve, bu süreçte ...",
#   'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/SiRbxzKw-hY/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/SiRbxzKw-hY/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/SiRbxzKw-hY/hqdefault.jpg',
#     'width': 480,
#     'height': 360}},
#   'channelTitle': 'Kodluyoruz',
#   'liveBroadcastContent': 'none',
#   'publishTime': '2023-12-29T14:41:51Z'}}

# %%
response["items"][0]['id']['videoId']
# Out:
# 'SiRbxzKw-hY'

# %%
response["items"][0]['snippet']['title']
# Out:
# 'Başarı Hikayesi | Murat Kiraz'

# %%
# for loop in response
for video in response["items"]:
    if video['id']['kind'] == "youtube#video":
        video_title = video['snippet']['title']
        print(video_title)
# Out:
# Başarı Hikayesi | Murat Kiraz
# Başarı Hikayesi | Murat Kiraz
# Kodluyoruz Adana Ideathon
# Kodluyoruz Yeni İşime Hazırlanıyorum (Ankara)
# Burak Tungut ile Ask Me Anything / Cloud Architect #kodluyoruz #yazılım
# Burak Tungut ile Ask Me Anything / Cloud Architect #kodluyoruz #yazılım
# Yazılım sektörünün önemli isimlerinden Salih Enver Yurter ile ASK ME ANYTHING  #kodluyoruz #yazılım
# Salih Enver Yurter (Managing Partner @ Avsos) ile Ask Me Anything!
# Yeni İşime Hazırlanıyorum Programı&#39;nda Neler Yapıyoruz? 🤔 🚀
# Siber Güvenlik: Geleceğe Yolculuk
# Hard Skills vs Soft Skills | w/Ali Ozan Koçak &amp; Anıl Taşkıran
# Hard Skills vs Soft Skills | w/ Ozan Koçak &amp; Anıl Taşkıran
# Daron Yöndem ile Ask Me Anything
# Kodluyoruz 7 yaşında! 🧡
# Yeni İşine Hazırlan: Mülakat Simülasyonu
# Yeni İşine Hazırlan: Mülakat Simülasyonu - 1. Bölüm
# Türkiye Cumhuriyeti&#39;nin 100. yıl Kutlu Olsun! 🇹🇷
# Tech&#39;n Talk &amp; Huawei
# Tecrübeli Yazılımcı vs Genç Yazılımcı Düello Etkinliği
# Start-up vs Kurumsal Düello Etkinliği
# Daron Yöndem ile Ask Me Anything
# Yazılımcı Olmanın Avantajları vs Dezavantajları
# Java vs JavaScript
# Siber Güvenlik: Geleceğe Yolculuk
# Harekete Geç Zirvesi Günümüz Teknolojileri &amp; İnovasyon ve Girişimcilik
# Harekete Geç Zirvesi Mobil Uygulama &amp; Oyun Geliştirme
# Harekete Geç Zirvesi AR-GE &amp; Veri Bilimi
# Harekete Geç Zirvesi WEB &amp; Siber Güvenlik
# Alaylı vs. Akademili| w/ Fulya Mercan &amp; Mercan Karacabey
# Midjourney vs. Dall.E 2 | w/ Ozan Sihay &amp; Tarık Bilen
# Topluluk vs. Bireysel Öğrenme | w/Kodluyoruz Üniversite Liderleri 🚀
# Kodlama Dünyası Kızlarla Güçleniyor🧡
# Tech&#39;n Talk | Teknoloji ve Yazılım Sektörünün Sesi
# Freelance vs. Maaşlı Çalışan | w/ Berkant Cen &amp; Ezran Onur Bayantemur
# 6 Soruda Siber Güvenlik Uzmanlığı
# Java vs Golang | w/Ali Onur Geven &amp; Ahmet Selim Kaya
# Tech&#39;n Talk | Teknoloji ve Yazılım Sektörünün Sesi
# Kodluyoruz 6 Yaşında  🚀
# Hi-Kod ile Kodlamaya Merhaba de!
# A&#39;dan Z&#39;ye Oyun Geliştirme: Oyun Başlasın!
# Oyun Sektöründe Girişimcilik Ve Oyun Yayınlama Süreçleri
# A&#39;dan Z&#39;ye Oyun Geliştirme: Unreal Engine ile Oyun Geliştirme ve Tasarım
# Şadi Evren Şeker ile Ask Me Anything
# A&#39;dan Z&#39;ye Oyun Geliştirme
# Kariyer Sohbetleri:Diplomasız Yazılımcı Olmak
# Ofiste Çalışmak vs. Evden Çalışmak
# Kariyer Sohbetleri: Veri Bilimi
# Tech&#39;n Talk | Teknoloji ve Yazılım Sektörünün Sesi
# Unity vs. Unreal | w/Özge Kocaoğlu &amp; Burak Akşahin
# Eğitimde Office 365 Araçlarının Önemi: Aydın Aslantaş

# %%
for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        video_title = video['snippet']['title']
        video_id = video['id']['videoId']
        upload_time = video['snippet']['publishedAt']
        upload_date= str(upload_time).split("T")[0]

        # collecting video statistics
        video_stats_url = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+YOUTUBE_API_KEY
        video_stats_response = requests.get(video_stats_url).json()

        view_count = video_stats_response['items'][0]["statistics"]["viewCount"]
        like_count = video_stats_response['items'][0]["statistics"]["likeCount"]

        print(video_title)
        print(video_id)
        print(upload_date)
        print(view_count)
        print(like_count)
        print("\n")
# Out:
# Başarı Hikayesi | Murat Kiraz
# SiRbxzKw-hY
# 2023-12-29
# 9
# 0
#
#
# Başarı Hikayesi | Murat Kiraz
# _8bXatPbwE4
# 2023-12-29
# 1
# 0
#
#
# Kodluyoruz Adana Ideathon
# hS6tJVmiPak
# 2023-12-27
# 254
# 5
#
#
# Kodluyoruz Yeni İşime Hazırlanıyorum (Ankara)
# CcgtvPJVwRs
# 2023-12-26
# 338
# 14
#
#
# Burak Tungut ile Ask Me Anything / Cloud Architect #kodluyoruz #yazılım
# 5ogRZC4aE9M
# 2023-12-14
# 238
# 6
#
#
# Burak Tungut ile Ask Me Anything / Cloud Architect #kodluyoruz #yazılım
# MYqI51JaE1E
# 2023-12-14
# 270
# 7
#
#
# Yazılım sektörünün önemli isimlerinden Salih Enver Yurter ile ASK ME ANYTHING  #kodluyoruz #yazılım
# qVEaxW7RYj0
# 2023-12-09
# 208
# 4
#
#
# Salih Enver Yurter (Managing Partner @ Avsos) ile Ask Me Anything!
# 6fv3EF5mWSA
# 2023-12-09
# 279
# 6
#
#
# Yeni İşime Hazırlanıyorum Programı&#39;nda Neler Yapıyoruz? 🤔 🚀
# 4cNY5iOabbg
# 2023-12-06
# 318
# 10
#
#
# Siber Güvenlik: Geleceğe Yolculuk
# E9D99p9mgx8
# 2023-11-30
# 254
# 6
#
#
# Hard Skills vs Soft Skills | w/Ali Ozan Koçak &amp; Anıl Taşkıran
# N-utisBoWLo
# 2023-11-30
# 155
# 3
#
#
# Hard Skills vs Soft Skills | w/ Ozan Koçak &amp; Anıl Taşkıran
# DmqMACSBQCg
# 2023-11-29
# 341
# 11
#
#
# Daron Yöndem ile Ask Me Anything
# s0WKxw9LE4U
# 2023-11-23
# 162
# 7
#
#
# Kodluyoruz 7 yaşında! 🧡
# fJ7Ca-EH3TI
# 2023-11-17
# 509
# 15
#
#
# Yeni İşine Hazırlan: Mülakat Simülasyonu
# zof6xLbxpZE
# 2023-11-07
# 268
# 10
#
#
# Yeni İşine Hazırlan: Mülakat Simülasyonu - 1. Bölüm
# 1hWdMu733VA
# 2023-11-07
# 1111
# 34
#
#
# Türkiye Cumhuriyeti&#39;nin 100. yıl Kutlu Olsun! 🇹🇷
# f1wx9EsQ9Hc
# 2023-10-27
# 649
# 25
#
#
# Tech&#39;n Talk &amp; Huawei
# 4rUMJwO-Vzg
# 2023-09-16
# 1036
# 50
#
#
# Tecrübeli Yazılımcı vs Genç Yazılımcı Düello Etkinliği
# buyirB6O9tg
# 2023-09-15
# 1022
# 31
#
#
# Start-up vs Kurumsal Düello Etkinliği
# 02-oQAbTg10
# 2023-08-25
# 683
# 33
#
#
# Daron Yöndem ile Ask Me Anything
# EbooRwlnxrY
# 2023-08-11
# 1252
# 59
#
#
# Yazılımcı Olmanın Avantajları vs Dezavantajları
# AmSe8DdH5Hg
# 2023-07-19
# 1587
# 88
#
#
# Java vs JavaScript
# E3JiEFDK0G4
# 2023-06-19
# 2293
# 94
#
#
# Siber Güvenlik: Geleceğe Yolculuk
# y-xthksY0yY
# 2023-06-14
# 800
# 40
#
#
# Harekete Geç Zirvesi Günümüz Teknolojileri &amp; İnovasyon ve Girişimcilik
# 19Dw7Vx1Y5U
# 2023-06-03
# 1715
# 58
#
#
# Harekete Geç Zirvesi Mobil Uygulama &amp; Oyun Geliştirme
# 8Swl6Jrq6eg
# 2023-06-03
# 1951
# 97
#
#
# Harekete Geç Zirvesi AR-GE &amp; Veri Bilimi
# lidiDtK6QyY
# 2023-06-03
# 2196
# 92
#
#
# Harekete Geç Zirvesi WEB &amp; Siber Güvenlik
# Hyry-yZ17uE
# 2023-06-03
# 3326
# 121
#
#
# Alaylı vs. Akademili| w/ Fulya Mercan &amp; Mercan Karacabey
# qPw6OEz4JlM
# 2023-05-24
# 1359
# 60
#
#
# Midjourney vs. Dall.E 2 | w/ Ozan Sihay &amp; Tarık Bilen
# o8-3QZ718Kk
# 2023-04-10
# 939
# 37
#
#
# Topluluk vs. Bireysel Öğrenme | w/Kodluyoruz Üniversite Liderleri 🚀
# 8IMOgsIWUgA
# 2023-03-20
# 910
# 40
#
#
# Kodlama Dünyası Kızlarla Güçleniyor🧡
# INI_5T6-2Wg
# 2023-03-08
# 805
# 33
#
#
# Tech&#39;n Talk | Teknoloji ve Yazılım Sektörünün Sesi
# 8NzoFKVJijQ
# 2023-02-04
# 1549
# 42
#
#
# Freelance vs. Maaşlı Çalışan | w/ Berkant Cen &amp; Ezran Onur Bayantemur
# 17hh5_CLcfw
# 2023-01-10
# 3928
# 161
#
#
# 6 Soruda Siber Güvenlik Uzmanlığı
# BNt1OB2PJuI
# 2023-01-09
# 1694
# 66
#
#
# Java vs Golang | w/Ali Onur Geven &amp; Ahmet Selim Kaya
# aMLfEGmWd6c
# 2022-12-13
# 2565
# 82
#
#
# Tech&#39;n Talk | Teknoloji ve Yazılım Sektörünün Sesi
# MkgqTJHMqes
# 2022-12-03
# 1739
# 57
#
#
# Kodluyoruz 6 Yaşında  🚀
# BbanJjsw_Ew
# 2022-11-30
# 1205
# 49
#
#
# Hi-Kod ile Kodlamaya Merhaba de!
# lPJf37SFG5o
# 2022-11-24
# 2910
# 90
#
#
# A&#39;dan Z&#39;ye Oyun Geliştirme: Oyun Başlasın!
# vbQxbFkIKtw
# 2022-11-08
# 890
# 39
#
#
# Oyun Sektöründe Girişimcilik Ve Oyun Yayınlama Süreçleri
# kwqWFn4roBw
# 2022-11-01
# 1116
# 43
#
#
# A&#39;dan Z&#39;ye Oyun Geliştirme: Unreal Engine ile Oyun Geliştirme ve Tasarım
# SET2MRiF5HU
# 2022-10-26
# 1419
# 62
#
#
# Şadi Evren Şeker ile Ask Me Anything
# KMx_6OrQW70
# 2022-10-25
# 5048
# 238
#
#
# A&#39;dan Z&#39;ye Oyun Geliştirme
# vlVSCYT4Sbs
# 2022-10-18
# 2390
# 107
#
#
# Kariyer Sohbetleri:Diplomasız Yazılımcı Olmak
# vk36mivy9UE
# 2022-10-14
# 6016
# 232
#
#
# Ofiste Çalışmak vs. Evden Çalışmak
# 4MuNeJH9PP8
# 2022-09-23
# 1084
# 34
#
#
# Kariyer Sohbetleri: Veri Bilimi
# zhamJScIHWE
# 2022-09-14
# 2029
# 98
#
#
# Tech&#39;n Talk | Teknoloji ve Yazılım Sektörünün Sesi
# 8fy7idN-YyU
# 2022-09-10
# 3288
# 137
#
#
# Unity vs. Unreal | w/Özge Kocaoğlu &amp; Burak Akşahin
# sno5uOOgzjU
# 2022-08-25
# 4294
# 187
#
#
# Eğitimde Office 365 Araçlarının Önemi: Aydın Aslantaş
# U75Lpq6dzpQ
# 2022-08-24
# 520
# 28

# %%
df = pd.DataFrame()  # Create an empty DataFrame

for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        # ... (extract video information)

        # Create a new DataFrame row for the current video
        video_df = pd.DataFrame({
            "video_id": video_id,
            "video_title": video_title,
            "upload_date": upload_date,
            "view_count": view_count,
            "like_count": like_count
        }, index=[0])  # Add an index to avoid potential issues

        # Concatenate the new row with the existing DataFrame
        df = pd.concat([df, video_df], ignore_index=True)

# Now df holds all the collected video information

# %%
def get_video_statistics(video_id, youtube_api_key):
    # collecting video statistics
    video_stats_url = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+youtube_api_key
    video_stats_response = requests.get(video_stats_url).json()

    view_count = video_stats_response['items'][0]["statistics"]["viewCount"]
    like_count = video_stats_response['items'][0]["statistics"]["likeCount"]

    return view_count, like_count

# %%
def get_videos_from_channel(df, channel_id, youtube_api_key):
    # API call
    pageToken = ""
    url = "https://www.googleapis.com/youtube/v3/search?key="+youtube_api_key+"&channelId="+channel_id+"&part=snippet,id&order=date&maxResults=1000"+pageToken
    
    response = requests.get(url).json()
    time.sleep(3)

    for video in response['items']:
        if video['id']['kind'] == 'youtube#video':
            video_title = video['snippet']['title']
            video_id = video['id']['videoId']
            upload_date = video['snippet']['publishedAt']
            upload_date= str(upload_date).split("T")[0]

            view_count, like_count = get_video_statistics(video_id, youtube_api_key)

            # save 
            df = df._append({
                "video_id": video_id,
                "video_title": video_title,
                "upload_date": upload_date,
                "view_count": view_count,
                "like_count": like_count
            }, 
            ignore_index = True
            )
    return df

# %%
CHANNEL_ID = "UCSnIf-v95OSGIv9H7d2R2lw"


df = pd.DataFrame(columns=["video_id","video_title","upload_date","view_count","like_count"]) 
youtube_data = get_videos_from_channel(df, CHANNEL_ID, YOUTUBE_API_KEY)

# %%
youtube_data.head(30)
# Out:
#        video_id                                        video_title  \
# 0   SiRbxzKw-hY                      Başarı Hikayesi | Murat Kiraz
# 1   _8bXatPbwE4                      Başarı Hikayesi | Murat Kiraz
# 2   hS6tJVmiPak                          Kodluyoruz Adana Ideathon
# 3   CcgtvPJVwRs      Kodluyoruz Yeni İşime Hazırlanıyorum (Ankara)
# 4   5ogRZC4aE9M  Burak Tungut ile Ask Me Anything / Cloud Archi...
# 5   MYqI51JaE1E  Burak Tungut ile Ask Me Anything / Cloud Archi...
# 6   qVEaxW7RYj0  Yazılım sektörünün önemli isimlerinden Salih E...
# 7   6fv3EF5mWSA  Salih Enver Yurter (Managing Partner @ Avsos) ...
# 8   4cNY5iOabbg  Yeni İşime Hazırlanıyorum Programı&#39;nda Nel...
# 9   E9D99p9mgx8                Siber Güvenlik: Geleceğe Yolculuk
# 10  N-utisBoWLo  Hard Skills vs Soft Skills | w/Ali Ozan Koçak ...
# 11  DmqMACSBQCg  Hard Skills vs Soft Skills | w/ Ozan Koçak &am...
# 12  s0WKxw9LE4U                  Daron Yöndem ile Ask Me Anything
# 13  fJ7Ca-EH3TI                            Kodluyoruz 7 yaşında! 🧡
# 14  zof6xLbxpZE           Yeni İşine Hazırlan: Mülakat Simülasyonu
# 15  1hWdMu733VA  Yeni İşine Hazırlan: Mülakat Simülasyonu - 1. ...
# 16  f1wx9EsQ9Hc  Türkiye Cumhuriyeti&#39;nin 100. yıl Kutlu Ols...
# 17  4rUMJwO-Vzg                       Tech&#39;n Talk &amp; Huawei
# 18  buyirB6O9tg  Tecrübeli Yazılımcı vs Genç Yazılımcı Düello E...
# 19  02-oQAbTg10              Start-up vs Kurumsal Düello Etkinliği
# 20  EbooRwlnxrY                   Daron Yöndem ile Ask Me Anything
# 21  AmSe8DdH5Hg    Yazılımcı Olmanın Avantajları vs Dezavantajları
# 22  E3JiEFDK0G4                                 Java vs JavaScript
# 23  y-xthksY0yY                  Siber Güvenlik: Geleceğe Yolculuk
# 24  19Dw7Vx1Y5U  Harekete Geç Zirvesi Günümüz Teknolojileri &am...
# 25  8Swl6Jrq6eg  Harekete Geç Zirvesi Mobil Uygulama &amp; Oyun...
# 26  lidiDtK6QyY       Harekete Geç Zirvesi AR-GE &amp; Veri Bilimi
# 27  Hyry-yZ17uE      Harekete Geç Zirvesi WEB &amp; Siber Güvenlik
# 28  qPw6OEz4JlM  Alaylı vs. Akademili| w/ Fulya Mercan &amp; Me...
# 29  o8-3QZ718Kk  Midjourney vs. Dall.E 2 | w/ Ozan Sihay &amp; ...
#
#    upload_date view_count like_count
# 0   2023-12-29         15          0
# 1   2023-12-29          1          0
# 2   2023-12-27        254          5
# 3   2023-12-26        338         14
# 4   2023-12-14        238          6
# 5   2023-12-14        270          7
# 6   2023-12-09        208          4
# 7   2023-12-09        279          6
# 8   2023-12-06        318         10
# 9   2023-11-30        254          6
# 10  2023-11-30        155          3
# 11  2023-11-29        341         11
# 12  2023-11-23        162          7
# 13  2023-11-17        509         15
# 14  2023-11-07        268         10
# 15  2023-11-07       1111         34
# 16  2023-10-27        649         25
# 17  2023-09-16       1036         50
# 18  2023-09-15       1022         31
# 19  2023-08-25        683         33
# 20  2023-08-11       1252         59
# 21  2023-07-19       1587         88
# 22  2023-06-19       2293         94
# 23  2023-06-14        800         40
# 24  2023-06-03       1715         58
# 25  2023-06-03       1951         97
# 26  2023-06-03       2196         92
# 27  2023-06-03       3326        121
# 28  2023-05-24       1359         60
# 29  2023-04-10        939         37
